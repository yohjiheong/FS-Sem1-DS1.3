# %% [markdown]
# # Decision Tree

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()
x = iris.data[:, 2:] # petal length and width
y = iris.target
feature_name = iris.feature_names[2:]

# %% [markdown]
# ## DecisionTree Modeling

# %%
gini_classifier = DecisionTreeClassifier()
gini_classifier.fit(x, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Build decision tree in both entropy and GINI

# %%
entropy_classifier = DecisionTreeClassifier(criterion = 'entropy')
entropy_classifier.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ## Convert to Decision Tree Diagram

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(gini_classifier, out_file = dot_data, filled = True, rounded=True, special_characters = True,
               feature_names = feature_name)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())

# %%
dot_data = StringIO()
export_graphviz(entropy_classifier, out_file = dot_data, filled = True, rounded=True, special_characters = True,
               feature_names = feature_name)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())
